# %% [markdown]
# ### SMART-Ziel
#
# Wir analysieren im JupyterLab-Notebook den Zusammenhang zwischen dem jährlichen Einkommen (AnnualIncome)
# und der Wahrscheinlichkeit, eine Reiseversicherung abzuschließen (TravelInsurance = 1),
# und belegen das Ganze mit deskriptiven Statistiken, Visualisierungen und einem statistischen Test
# und beantworten damit die Frage, ob höheres Einkommen mit höherer Abschlusswahrscheinlichkeit einhergeht.
# Fertig bis 20.11. Abends.
